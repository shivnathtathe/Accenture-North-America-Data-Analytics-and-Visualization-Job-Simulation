# %% [markdown]
# ### Importing all the libs.

# %%
import os

# %%
dirs = os.listdir()
dirs
# Out:
# ['.ipynb_checkpoints',
#  'Content (1).csv',
#  'Reactions (1).csv',
#  'ReactionTypes (1).csv',
#  'Task2.ipynb']

# %%
import pandas as pd
import numpy as np

# %%
dataset1 =  pd.read_csv(dirs[1])

# %%
dataset1.shape
# Out:
# (1000, 6)

# %%
dataset1.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
dataset1.isna().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
dataset1.dropna(inplace=True)

# %%
dataset1.isna().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
dataset1.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
dataset1.isna().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
dataset1.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Category', 'URL'], dtype='object')

# %%
dataset1.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset1
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
# ...

# %%
dataset2 = pd.read_csv(dirs[2])

# %%
dataset2
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
dataset2.isna().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
dataset2.dropna(inplace=True)

# %%
dataset2.isna().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
dataset2.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID        Type             Datetime
# 1  5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# 5  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4  interested  2020-08-23 12:25:58

# %%
dataset2.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
dataset2.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset2.head()
# Out:
#                              Content ID                               User ID  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#          Type             Datetime
# 1     disgust  2020-11-07 09:43:50
# 2     dislike  2021-06-17 12:22:51
# 3      scared  2021-04-18 05:13:58
# 4     disgust  2021-01-06 19:13:01
# 5  interested  2020-08-23 12:25:58

# %%
dataset2['Datetime'] = pd.to_datetime(dataset2['Datetime'])

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 1 to 25552
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  22534 non-null  object
#  1   User ID     22534 non-null  object
#  2   Type        22534 non-null  object
#  3   Datetime    22534 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 880.2+ KB

# %%
dataset3 =  pd.read_csv(dirs[3])

# %%
dataset3
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 640.0+ bytes

# %%
dataset3.isna().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %% [markdown]
# Here we don't need to drop NaN values

# %%
dataset3.columns
# Out:
# Index(['Unnamed: 0', 'Type', 'Sentiment', 'Score'], dtype='object')

# %%
dataset3.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset3
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 801 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  801 non-null    object
#  1   User ID     801 non-null    object
#  2   Type        801 non-null    object
#  3   Category    801 non-null    object
#  4   URL         801 non-null    object
# dtypes: object(5)
# memory usage: 37.5+ KB

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 1 to 25552
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  22534 non-null  object
#  1   User ID     22534 non-null  object
#  2   Type        22534 non-null  object
#  3   Datetime    22534 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 880.2+ KB

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Type       16 non-null     object
#  1   Sentiment  16 non-null     object
#  2   Score      16 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes

# %%
merged_data
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 1      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 2      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 3      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 4      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# ...

# %%
dataset1.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Category', 'URL'], dtype='object')

# %%
dataset2.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
dataset3.columns
# Out:
# Index(['Type', 'Sentiment', 'Score'], dtype='object')

# %%
merged_data = pd.merge(dataset1, dataset2, on=['Content ID'], how='inner')

# %%
merged_data
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 1      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 2      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 3      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 4      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# ...

# %%
dataset3 = dataset3.rename(columns={'Type':'Type_y'})

# %%
dataset3
# Out:
#          Type_y Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
merged_data = pd.merge(merged_data, dataset3, on='Type_y', how='left')

# %%
merged_data
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 1      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 2      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 3      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# 4      8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo    Studying
# ...

# %%
category_scores = merged_data.groupby('Category')['Score'].sum().reset_index()

# %%
category_scores
# Out:
#            Category  Score
# 0          Studying   1176
# 1           animals  52443
# 2           cooking  49681
# 3           culture  47710
# 4              dogs  41816
# 5         education  45103
# 6           fitness  41829
# 7              food  47576
# 8    healthy eating  52745
# 9   public speaking  37730
# 10          science  53657
# 11           soccer  42031
# 12         studying  34685
# 13       technology  46683
# 14           tennis  43612
# 15           travel  53935
# 16         veganism  38513

# %%
top_5_categories = category_scores.nlargest(5, 'Score')

# %%
top_5_categories
# Out:
#           Category  Score
# 15          travel  53935
# 10         science  53657
# 8   healthy eating  52745
# 1          animals  52443
# 2          cooking  49681

# %%
merged_data.to_csv('Accenture_Task2.csv', index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 92ED-43CF
#
#  Directory of C:\Users\91952\Desktop\Accenture Task
#
# 31-12-2023  07:28    <DIR>          .
# 31-12-2023  06:39    <DIR>          ..
# 31-12-2023  06:40    <DIR>          .ipynb_checkpoints
# 31-12-2023  07:28         4,516,821 Accenture_Task2.csv
# 31-12-2023  06:38           157,543 Content (1).csv
# 31-12-2023  07:28         4,516,821 Final_Task.csv
# 31-12-2023  06:38         2,650,513 Reactions (1).csv
# 31-12-2023  06:38               388 ReactionTypes (1).csv
# 31-12-2023  07:28           101,003 Task2.ipynb
#                6 File(s)     11,943,089 bytes
#                3 Dir(s)  127,235,735,552 bytes free

# %%
merged_data.shape
# Out:
# (18384, 10)
